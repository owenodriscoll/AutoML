# %% [markdown]
# Import packages

# %%
import sys
import os
import sklearn
import pprint # to neatly print dictionary results
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.datasets import fetch_california_housing # convenient dataset for continuous regression
from sklearn.metrics import r2_score, median_absolute_error

# %% [markdown]
# Install and Import custom package
# install: `python3 -m pip install py-automl-lib`
#
# or, if you want to enable feature-importance analyses
# install: `python3 -m pip install py-automl-lib[shap]`

# %%
from automl import AutomatedRegression

# %% [markdown]
# Prepare dataset

# %%
dataset = fetch_california_housing()
X_full, y_full = dataset.data, dataset.target
y = pd.DataFrame(y_full, columns = dataset.target_names)
X = pd.DataFrame(X_full, columns = dataset.feature_names)

# %% [markdown]
# # Contents
# - ### 1: minimal run
#     - Basic automated regresion using linear models
# - ### 2: non-linearizing linear regressors
#     - Adding non-linear transformations to data in `AutomatedRegression` prior to regression
# - ### 3: additional weak predictors
#     - Adding additional, but worse, models to the stacked regression
# - ### 4: combining models
#     - Training seperately linear models and boosted models, then combine to train stacked model
# - ### 5: continue model training
#     - Add trials to existing model
# - ### 6: multithreading
#     - Speeding up model training
# - ### 7: feature importance
#     - Feature importance with `shap`
# - ### 8: reloading a model
#     - Using joblib

# %% [markdown]
# ##  Regression #1: minimal run
# Select two linear regressors and optimize them towards maximizing the $R^2$ score on the training fraction (1 - `test_frac`). Regression is assessed on the test fraction of data using metrics `r2_score` and `median_absolute_error`.

# %%
result1 = AutomatedRegression(
    y = y,
    X = X,
    test_frac = 0.2,
    n_trial = 10,
    write_folder = 'testdir/test1',
    metric_optimise = r2_score,
    metric_assess = [r2_score, median_absolute_error],
    optimisation_direction = 'maximize',
    models_to_optimize = ['bayesianridge', 'lassolars',],
    models_to_assess = ['bayesianridge', 'lassolars'],
    )

# %%
result1.apply()
# Out:
# [I 2024-01-27 20:08:57,045] A new study created in RDB with name: regression_bayesianridge
# [I 2024-01-27 20:08:59,477] Trial 0 finished with value: 0.5719430386682233 and parameters: {'scaler': 'minmax', 'max_iter': 71, 'tol': 15.59945204206032, 'alpha_1': 3.809220577048033e-08, 'alpha_2': 4.589458612326471, 'lambda_1': 0.010260065124896791, 'lambda_2': 0.12042752972516801, 'transformers': 'quantile_trans', 'n_quantiles': 3400}. Best is trial 0 with value: 0.5719430386682233.
# [I 2024-01-27 20:09:05,889] Trial 1 finished with value: 0.5720389460061704 and parameters: {'scaler': 'robust', 'max_iter': 215, 'tol': 43.19450186989213, 'alpha_1': 8.171304639059403e-06, 'alpha_2': 0.013137990612765096, 'lambda_1': 2.4827821051950883e-07, 'lambda_2': 8.345387083873532e-06, 'transformers': 'quantile_trans', 'n_quantiles': 3200}. Best is trial 1 with value: 0.5720389460061704.
# [I 2024-01-27 20:09:08,681] Trial 2 finished with value: 0.6114513024491934 and parameters: {'scaler': 'standard', 'max_iter': 247, 'tol': 17.052412377023913, 'alpha_1': 4.472145552469491e-08, 'alpha_2': 30.821613670416532, 'lambda_1': 45.32317553128077, 'lambda_2': 1.2133147609286499, 'transformers': None}. Best is trial 2 with value: 0.6114513024491934.
# [I 2024-01-27 20:09:08,938] Trial 3 pruned.
# [I 2024-01-27 20:09:11,742] Trial 4 finished with value: 0.6114611490971495 and parameters: {'scaler': None, 'max_iter': 243, 'tol': 92.18742350309294, 'alpha_1': 7.672290184186785e-08, 'alpha_2': 9.116510241437162e-07, 'lambda_1': 2.833171661121252e-08, 'lambda_2': 1.791856834969136e-05, 'transformers': None}. Best is trial 4 with value: 0.6114611490971495.
# [I 2024-01-27 20:09:18,622] Trial 5 finished with value: 0.5719610134626957 and parameters: {'scaler': None, 'max_iter': 65, 'tol': 80.21969807738199, 'alpha_1': 5.5655288302015325e-08, 'alpha_2': 73.9382838287635, 'lambda_1': 0.5277736371601186, 'lambda_2': 9.708604629077578e-07, 'transformers': 'quantile_trans', 'n_quantiles': 2900}. Best is trial 4 with value: 0.6114611490971495.
# [I 2024-01-27 20:09:20,840] Trial 6 pruned.
# [I 2024-01-27 20:09:23,834] Trial 7 finished with value: 0.5720280777268731 and parameters: {'scaler': None, 'max_iter': 307, 'tol': 56.127719761336856, 'alpha_1': 0.5124739561946077, 'alpha_2': 0.0008668739724852811, 'lambda_1': 0.0016878284140548435, 'lambda_2': 0.00018854290037136504, 'transformers': 'quantile_trans', 'n_quantiles': 200}. Best is trial 4 with value: 0.6114611490971495.
# [I 2024-01-27 20:09:30,644] Trial 8 finished with value: 0.5720404975889243 and parameters: {'scaler': 'robust', 'max_iter': 107, 'tol': 41.038292309459145, 'alpha_1': 0.3593448171877907, 'alpha_2': 1.9408038941379893e-06, 'lambda_1': 5.885713232276734e-08, 'lambda_2': 7.897952712237135e-06, 'transformers': 'quantile_trans', 'n_quantiles': 3300}. Best is trial 4 with value: 0.6114611490971495.
# [I 2024-01-27 20:09:31,045] Trial 9 pruned.
# [I 2024-01-27 20:09:31,083] A new study created in RDB with name: regression_lassolars
# [I 2024-01-27 20:09:32,718] Trial 0 finished with value: 0.5720856425613432 and parameters: {'scaler': None, 'alpha': 1.6637118299520215e-06, 'random_state': 42, 'transformers': 'quantile_trans', 'n_quantiles': 3800}. Best is trial 0 with value: 0.5720856425613432.
# [I 2024-01-27 20:09:32,976] Trial 1 finished with value: -0.00021537376071165682 and parameters: {'scaler': 'standard', 'alpha': 52.21807133673529, 'random_state': 42, 'transformers': None}. Best is trial 0 with value: 0.5720856425613432.
# [I 2024-01-27 20:09:33,201] Trial 2 finished with value: 0.6051833273162363 and parameters: {'scaler': None, 'alpha': 0.012463595329542002, 'random_state': 42, 'transformers': None}. Best is trial 2 with value: 0.6051833273162363.
# [I 2024-01-27 20:09:33,379] Trial 3 finished with value: 0.6011170226678518 and parameters: {'scaler': 'minmax', 'alpha': 0.0007843819708428273, 'random_state': 42, 'transformers': None}. Best is trial 2 with value: 0.6051833273162363.
# [I 2024-01-27 20:09:35,234] Trial 4 finished with value: 0.5682073120654387 and parameters: {'scaler': 'minmax', 'alpha': 4.762459848032179e-05, 'random_state': 42, 'transformers': 'quantile_trans', 'n_quantiles': 2200}. Best is trial 2 with value: 0.6051833273162363.
# [I 2024-01-27 20:09:35,488] Trial 5 finished with value: 0.5720820288190642 and parameters: {'scaler': 'minmax', 'alpha': 2.557121805028817e-08, 'random_state': 42, 'transformers': 'quantile_trans', 'n_quantiles': 100}. Best is trial 2 with value: 0.6051833273162363.
# [I 2024-01-27 20:09:35,593] Trial 6 pruned.
# [I 2024-01-27 20:09:37,370] Trial 7 finished with value: 0.5720745477910725 and parameters: {'scaler': 'standard', 'alpha': 3.7967873783487925e-06, 'random_state': 42, 'transformers': 'quantile_trans', 'n_quantiles': 2300}. Best is trial 2 with value: 0.6051833273162363.
# [I 2024-01-27 20:09:37,449] Trial 8 pruned.
# [I 2024-01-27 20:09:37,554] Trial 9 pruned.
# [I 2024-01-27 20:09:37,576] Using an existing study with name 'regression_bayesianridge' instead of creating a new one.
# [I 2024-01-27 20:09:37,620] Using an existing study with name 'regression_lassolars' instead of creating a new one.

# %%
pprint.pprint(result1.summary)
plt.scatter(result1.y_pred, result1.y_test, s = 0.5); plt.plot([0,5], [0,5], '--k'); 
plt.xlim([0,5]); plt.ylim([0,5]); plt.xlabel("Prediction"); _ = plt.ylabel("Validation")
# Out:
# {'bayesianridge_best': [[0.5745683104138556, 0.04503346966789694],
#                         [0.4126136119433089, 0.01781949942063944]],
#  'lassolars_best': [[0.5836617695331479, 0.019466865289686663],
#                     [0.41681839445316216, 0.012251609884738864]],
#  'stacked': [[0.5760782761749214, 0.04217594066830962],
#              [0.4113213154082769, 0.017024345055679294]]}

# %% [markdown]
# The first row contains the first assessment metric, `r2_score`, with the second being `median_absolute_error`. The second column contains the standard deviation on 5-fold cross validation of the test fraction. Cross validation can be tweaked to preference by supplying a different `cross_validation` input to the `AutomatedRegression` class.
#
# The `bayesianridge` regressor performs worse than `lassolars` on the $R^{2}$ metric but better on the MAE. The stacked regressor is slightly between the two.

# %% [markdown]
# ##  Regression #2: non-linearizing linear regressors
# We add a spline transformation to the previous regression. This adds non-linearity to the `X`-matrix which can improve performance of linear models on non-linear data.
#
# However, the addition of a spline transformation can penalize performance if its unsuitable for the data or model. Since this is not desireable, the optimization tests the performance both with and without spline transformations. Therefore, even if the inclusion of a spline is specified through `spline_value`, optimisation might return an optimized model without any spline transformations.
#
# In addition to splines, two further transformations are supplied, namely: `poly_value` and `pca_value`. The former performs a polynomial expansion on the `X`-matrix, which can be benifitical if, for instance, the product of `X[param1]` and `X[param2]` contains more information than the individual parameters. Furthermore, the added degrees of freedom tend to be beneficial to linear models. However, polynomial expansions yield an exponential growth in parameters which can significantly increase training time (and memory requirements). If a lot of redundant information is supplied, consider applying a PCA compression on the `X`-matrix using `pca_value`. This can significantly reduce parameters with low variance, though, if these parameters are nonetheless important for regression, this will negatively affect performance.
#
# If all are provided, the transformations are applied in the order:
# <br>
# $\qquad$ X --> polynomial expansion -- > spline transformation --> (`X`-scaler) --> PCA compression --> regression --> $\hat{\textit{y}}$
# <br>
# The `X`-scaler is automatically included (even when no other transformations are specified). It performs standard transformations on the `X`-matrix such as MinMax, Standard, Robust (all from the sklearn library) or no scaling. Splines, polynomial expansions, `X`-scalers and pca compression are all applied seperately on the training and testing dataset to avoid data leakage

# %%
result2 = AutomatedRegression(
    y=y,
    X=X,
    test_frac = 0.2,
    n_trial=10,
    write_folder='testdir/test2',
    metric_optimise=r2_score,
    metric_assess=[r2_score, median_absolute_error],
    optimisation_direction='maximize',
    models_to_optimize=['bayesianridge', 'lassolars',],
    models_to_assess=['bayesianridge', 'lassolars'],
    spline_value={'n_knots': 10, 'degree':3},
    # poly_value={'degree': 2, 'interaction_only'= True},
    # pca_value={'n_components': 0.95},
    )

# %%
result2.apply()
# Out:
# [I 2024-01-27 19:29:03,836] A new study created in RDB with name: regression_bayesianridge
# [I 2024-01-27 19:29:04,726] Trial 0 finished with value: 0.6114649964157707 and parameters: {'scaler': 'minmax', 'feature_combo': False, 'max_iter': 32, 'tol': 86.61761457883176, 'alpha_1': 0.010260065124896791, 'alpha_2': 0.12042752972516801, 'lambda_1': 1.6063676259174453e-08, 'lambda_2': 50.01479828856935, 'transformers': None}. Best is trial 0 with value: 0.6114649964157707.
# [I 2024-01-27 19:29:09,706] Trial 1 finished with value: 0.5720784449071958 and parameters: {'scaler': 'robust', 'feature_combo': False, 'max_iter': 249, 'tol': 13.949386073809247, 'alpha_1': 8.345387083873532e-06, 'alpha_2': 4.609124432595992e-05, 'lambda_1': 0.0003636636071695854, 'lambda_2': 0.7108199592296855, 'transformers': 'quantile_trans', 'n_quantiles': 2400}. Best is trial 0 with value: 0.6114649964157707.
# [I 2024-01-27 19:29:26,207] Trial 2 finished with value: 0.261293164123202 and parameters: {'scaler': 'minmax', 'feature_combo': True, 'spline_value': {'degree': 3, 'extrapolation': 'constant', 'include_bias': True, 'knots': 'uniform', 'n_knots': 10, 'order': 'C', 'sparse_output': False}, 'max_iter': 326, 'tol': 30.461376924290935, 'alpha_1': 9.478096804784244e-08, 'alpha_2': 0.06955530592645753, 'lambda_1': 0.0002520721916536751, 'lambda_2': 1.661048634233462e-07, 'transformers': None}. Best is trial 0 with value: 0.6114649964157707.
# [I 2024-01-27 19:29:31,910] Trial 3 pruned.
# [I 2024-01-27 19:29:48,657] Trial 4 finished with value: 0.7002165681369061 and parameters: {'scaler': 'robust', 'feature_combo': True, 'spline_value': {'degree': 3, 'extrapolation': 'constant', 'include_bias': True, 'knots': 'uniform', 'n_knots': 10, 'order': 'C', 'sparse_output': False}, 'max_iter': 149, 'tol': 28.093450975928732, 'alpha_1': 0.0026727653447901085, 'alpha_2': 2.5659149064328484e-07, 'lambda_1': 1.0518887432316704, 'lambda_2': 5.5655288302015325e-08, 'transformers': None}. Best is trial 4 with value: 0.7002165681369061.
# [I 2024-01-27 19:29:54,055] Trial 5 pruned.
# [I 2024-01-27 19:29:59,549] Trial 6 pruned.
# [I 2024-01-27 19:30:10,814] Trial 7 pruned.
# [I 2024-01-27 19:30:22,241] Trial 8 pruned.
# [I 2024-01-27 19:30:27,954] Trial 9 pruned.
# [I 2024-01-27 19:30:27,991] A new study created in RDB with name: regression_lassolars
# [I 2024-01-27 19:30:28,260] Trial 0 finished with value: -0.00021537376071165682 and parameters: {'scaler': 'standard', 'feature_combo': True, 'spline_value': {'degree': 3, 'extrapolation': 'constant', 'include_bias': True, 'knots': 'uniform', 'n_knots': 10, 'order': 'C', 'sparse_output': False}, 'alpha': 12.096475764739722, 'random_state': 42, 'transformers': None}. Best is trial 0 with value: -0.00021537376071165682.
# [I 2024-01-27 19:30:31,544] Trial 1 finished with value: -0.0541832031396249 and parameters: {'scaler': 'minmax', 'feature_combo': False, 'alpha': 0.19149766645100244, 'random_state': 42, 'transformers': 'quantile_trans', 'n_quantiles': 2600}. Best is trial 0 with value: -0.00021537376071165682.
# [I 2024-01-27 19:30:31,761] Trial 2 finished with value: 0.6091221112279888 and parameters: {'scaler': 'standard', 'feature_combo': False, 'alpha': 0.008108292962302002, 'random_state': 42, 'transformers': None}. Best is trial 2 with value: 0.6091221112279888.
# [I 2024-01-27 19:30:32,012] Trial 3 finished with value: -0.054249103987695294 and parameters: {'scaler': 'standard', 'feature_combo': False, 'alpha': 23.296993975101238, 'random_state': 42, 'transformers': 'quantile_trans', 'n_quantiles': 500}. Best is trial 2 with value: 0.6091221112279888.
# [I 2024-01-27 19:30:32,105] Trial 4 pruned.
# [I 2024-01-27 19:30:32,721] Trial 5 finished with value: -0.00021537376071165682 and parameters: {'scaler': 'minmax', 'feature_combo': True, 'spline_value': {'degree': 3, 'extrapolation': 'constant', 'include_bias': True, 'knots': 'uniform', 'n_knots': 10, 'order': 'C', 'sparse_output': False}, 'alpha': 9.356266843604287, 'random_state': 42, 'transformers': None}. Best is trial 2 with value: 0.6091221112279888.
# [I 2024-01-27 19:30:32,802] Trial 6 pruned.
# [I 2024-01-27 19:30:36,545] Trial 7 finished with value: 0.6787676833866643 and parameters: {'scaler': 'standard', 'feature_combo': True, 'spline_value': {'degree': 3, 'extrapolation': 'constant', 'include_bias': True, 'knots': 'uniform', 'n_knots': 10, 'order': 'C', 'sparse_output': False}, 'alpha': 2.3577126571566896e-06, 'random_state': 42, 'transformers': 'quantile_trans', 'n_quantiles': 2600}. Best is trial 7 with value: 0.6787676833866643.
# [I 2024-01-27 19:30:36,643] Trial 8 pruned.
# [I 2024-01-27 19:30:36,793] Trial 9 pruned.
# [I 2024-01-27 19:30:36,817] Using an existing study with name 'regression_bayesianridge' instead of creating a new one.
# /Users/opodriscoll/miniconda3/envs/to_delete/lib/python3.11/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains {'degree': 3, 'extrapolation': 'constant', 'include_bias': True, 'knots': 'uniform', 'n_knots': 10, 'order': 'C', 'sparse_output': False} which is of type dict.
#   warnings.warn(message)
# [I 2024-01-27 19:30:36,870] Using an existing study with name 'regression_lassolars' instead of creating a new one.
# /Users/opodriscoll/miniconda3/envs/to_delete/lib/python3.11/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains {'degree': 3, 'extrapolation': 'constant', 'include_bias': True, 'knots': 'uniform', 'n_knots': 10, 'order': 'C', 'sparse_output': False} which is of type dict.
#   warnings.warn(message)

# %%
pprint.pprint(result2.summary)
plt.scatter(result2.y_pred, result2.y_test, s = 0.5); plt.plot([0,5], [0,5], '--k'); 
plt.xlim([0,5]); plt.ylim([0,5]); plt.xlabel("Prediction"); _ = plt.ylabel("Validation")
# Out:
# {'bayesianridge_best': [[0.6166525801393758, 0.11977394809151548],
#                         [0.33962362540388663, 0.008000757012443576]],
#  'lassolars_best': [[0.6548792139545462, 0.018608405994477904],
#                     [0.3101030987375952, 0.006318461547672059]],
#  'stacked': [[0.6492049743642887, 0.06948533686345658],
#              [0.3317683893119493, 0.007792515911442625]]}

# %% [markdown]
# Indeed performance of linear methods `bayesianridge` and `lassolars`improves significantly after the spline transformation

# %% [markdown]
# ##  Regression #3: additional weak predictors
# The final regression is performed by applying a `Ridge` regressor on the output of the previous regressors, i.e. stacking. The idea being that the final regressor learns from the combination of original results, thereby allowing it to make a new and improved prediction. To increase diversity for the final stacking operation, additional weak predictors can be added. These are versions of the same regressor but for whom the performance was less than the best performing model.

# %%
result3 = AutomatedRegression(
    y=y,
    X=X,
    test_frac = 0.2,
    n_trial=10,
    write_folder='testdir/test3',
    metric_optimise = r2_score,
    metric_assess = [r2_score, median_absolute_error],
    optimisation_direction = 'maximize',
    models_to_optimize=['bayesianridge', 'lassolars'],
    models_to_assess=['bayesianridge', 'lassolars'],
    spline_value={'n_knots': 10, 'degree':3},
    n_weak_models=3
    )

# %%
result3.apply()
# Out:
# [I 2024-01-27 19:30:43,865] A new study created in RDB with name: regression_bayesianridge
# [I 2024-01-27 19:30:44,760] Trial 0 finished with value: 0.6114649964157707 and parameters: {'scaler': 'minmax', 'feature_combo': False, 'max_iter': 32, 'tol': 86.61761457883176, 'alpha_1': 0.010260065124896791, 'alpha_2': 0.12042752972516801, 'lambda_1': 1.6063676259174453e-08, 'lambda_2': 50.01479828856935, 'transformers': None}. Best is trial 0 with value: 0.6114649964157707.
# [I 2024-01-27 19:30:50,039] Trial 1 finished with value: 0.5720784449071958 and parameters: {'scaler': 'robust', 'feature_combo': False, 'max_iter': 249, 'tol': 13.949386073809247, 'alpha_1': 8.345387083873532e-06, 'alpha_2': 4.609124432595992e-05, 'lambda_1': 0.0003636636071695854, 'lambda_2': 0.7108199592296855, 'transformers': 'quantile_trans', 'n_quantiles': 2400}. Best is trial 0 with value: 0.6114649964157707.
# [I 2024-01-27 19:31:06,411] Trial 2 finished with value: 0.261293164123202 and parameters: {'scaler': 'minmax', 'feature_combo': True, 'spline_value': {'degree': 3, 'extrapolation': 'constant', 'include_bias': True, 'knots': 'uniform', 'n_knots': 10, 'order': 'C', 'sparse_output': False}, 'max_iter': 326, 'tol': 30.461376924290935, 'alpha_1': 9.478096804784244e-08, 'alpha_2': 0.06955530592645753, 'lambda_1': 0.0002520721916536751, 'lambda_2': 1.661048634233462e-07, 'transformers': None}. Best is trial 0 with value: 0.6114649964157707.
# [I 2024-01-27 19:31:11,725] Trial 3 pruned.
# [I 2024-01-27 19:31:28,644] Trial 4 finished with value: 0.7002165681369061 and parameters: {'scaler': 'robust', 'feature_combo': True, 'spline_value': {'degree': 3, 'extrapolation': 'constant', 'include_bias': True, 'knots': 'uniform', 'n_knots': 10, 'order': 'C', 'sparse_output': False}, 'max_iter': 149, 'tol': 28.093450975928732, 'alpha_1': 0.0026727653447901085, 'alpha_2': 2.5659149064328484e-07, 'lambda_1': 1.0518887432316704, 'lambda_2': 5.5655288302015325e-08, 'transformers': None}. Best is trial 4 with value: 0.7002165681369061.
# [I 2024-01-27 19:31:34,339] Trial 5 pruned.
# [I 2024-01-27 19:31:39,811] Trial 6 pruned.
# [I 2024-01-27 19:31:50,774] Trial 7 pruned.
# [I 2024-01-27 19:32:01,549] Trial 8 pruned.
# [I 2024-01-27 19:32:07,255] Trial 9 pruned.
# [I 2024-01-27 19:32:07,293] A new study created in RDB with name: regression_lassolars
# [I 2024-01-27 19:32:07,643] Trial 0 finished with value: -0.00021537376071165682 and parameters: {'scaler': 'standard', 'feature_combo': True, 'spline_value': {'degree': 3, 'extrapolation': 'constant', 'include_bias': True, 'knots': 'uniform', 'n_knots': 10, 'order': 'C', 'sparse_output': False}, 'alpha': 12.096475764739722, 'random_state': 42, 'transformers': None}. Best is trial 0 with value: -0.00021537376071165682.
# [I 2024-01-27 19:32:11,091] Trial 1 finished with value: -0.0541832031396249 and parameters: {'scaler': 'minmax', 'feature_combo': False, 'alpha': 0.19149766645100244, 'random_state': 42, 'transformers': 'quantile_trans', 'n_quantiles': 2600}. Best is trial 0 with value: -0.00021537376071165682.
# [I 2024-01-27 19:32:11,286] Trial 2 finished with value: 0.6091221112279888 and parameters: {'scaler': 'standard', 'feature_combo': False, 'alpha': 0.008108292962302002, 'random_state': 42, 'transformers': None}. Best is trial 2 with value: 0.6091221112279888.
# [I 2024-01-27 19:32:11,558] Trial 3 finished with value: -0.054249103987695294 and parameters: {'scaler': 'standard', 'feature_combo': False, 'alpha': 23.296993975101238, 'random_state': 42, 'transformers': 'quantile_trans', 'n_quantiles': 500}. Best is trial 2 with value: 0.6091221112279888.
# [I 2024-01-27 19:32:11,665] Trial 4 pruned.
# [I 2024-01-27 19:32:12,235] Trial 5 finished with value: -0.00021537376071165682 and parameters: {'scaler': 'minmax', 'feature_combo': True, 'spline_value': {'degree': 3, 'extrapolation': 'constant', 'include_bias': True, 'knots': 'uniform', 'n_knots': 10, 'order': 'C', 'sparse_output': False}, 'alpha': 9.356266843604287, 'random_state': 42, 'transformers': None}. Best is trial 2 with value: 0.6091221112279888.
# [I 2024-01-27 19:32:12,350] Trial 6 pruned.
# [I 2024-01-27 19:32:16,214] Trial 7 finished with value: 0.6787676833866643 and parameters: {'scaler': 'standard', 'feature_combo': True, 'spline_value': {'degree': 3, 'extrapolation': 'constant', 'include_bias': True, 'knots': 'uniform', 'n_knots': 10, 'order': 'C', 'sparse_output': False}, 'alpha': 2.3577126571566896e-06, 'random_state': 42, 'transformers': 'quantile_trans', 'n_quantiles': 2600}. Best is trial 7 with value: 0.6787676833866643.
# [I 2024-01-27 19:32:16,292] Trial 8 pruned.
# [I 2024-01-27 19:32:16,403] Trial 9 pruned.
# [I 2024-01-27 19:32:16,426] Using an existing study with name 'regression_bayesianridge' instead of creating a new one.
# /Users/opodriscoll/miniconda3/envs/to_delete/lib/python3.11/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains {'degree': 3, 'extrapolation': 'constant', 'include_bias': True, 'knots': 'uniform', 'n_knots': 10, 'order': 'C', 'sparse_output': False} which is of type dict.
#   warnings.warn(message)
# [I 2024-01-27 19:32:16,561] Using an existing study with name 'regression_lassolars' instead of creating a new one.
# /Users/opodriscoll/miniconda3/envs/to_delete/lib/python3.11/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains {'degree': 3, 'extrapolation': 'constant', 'include_bias': True, 'knots': 'uniform', 'n_knots': 10, 'order': 'C', 'sparse_output': False} which is of type dict.
#   warnings.warn(message)

# %%
pprint.pprint(result3.summary)
plt.scatter(result3.y_pred, result3.y_test, s = 0.5); plt.plot([0,5], [0,5], '--k'); 
plt.xlim([0,5]); plt.ylim([0,5]); plt.xlabel("Prediction"); _ = plt.ylabel("Validation")
# Out:
# {'bayesianridge_0': [[0.574648684778255, 0.04491854111867346],
#                      [0.4118712015771207, 0.017609952450281043]],
#  'bayesianridge_1': [[0.5499583665812334, 0.016469258007420332],
#                      [0.3647563927708298, 0.007060951395038324]],
#  'bayesianridge_2': [[0.639288152525258, 0.07935482921565686],
#                      [0.3356755714271468, 0.01047799389840974]],
#  'bayesianridge_best': [[0.6166525801393758, 0.11977394809151548],
#                         [0.33962362540388663, 0.008000757012443576]],
#  'lassolars_0': [[-0.0007957517926284741, 0.0008177019377945391],
#                  [0.7586575499031007, 0.025822381370999646]],
#  'lassolars_2': [[0.5803246918518472, 0.029622316889292673],
#                  [0.4130619851808441, 0.015543537764640717]],
#  'lassolars_5': [[-0.0007957517926284741, 0.0008177019377945391],
#                  [0.7586575499031007, 0.025822381370999646]],
#  'lassolars_best': [[0.6548792139545462, 0.018608405994477904],
#                     [0.3101030987375952, 0.006318461547672059]],
#  'stacked': [[0.6504031933696516, 0.06517967859816315],
#              [0.329260196966247, 0.009067205220671884]]}

# %% [markdown]
# The `stacked` regressor indeed slightly improves over the previous result despite including several worse performing models.

# %% [markdown]
# ##  Regression #4: combining models
# Linear regressors are nice because they train fast and run efficiently but depending on the regression objective, diffferent regression models might outperform a linear model. Here we combine both linear and boosted models
#
# First we set up a class instance containing two linear methods with optional spline transformations. We apply the hyperoptimisation. Next we create a new class instance with boosted methods which we write to the same folder as the previous linear models. Since linear methods generally train faster, less trials are allocated to them with more trials to the boosted methods. In the second class instance we assess the performance for all four models (as they are saved to the same directory) with an additional five weak predictors to make our final estimate.

# %%
result4_1 = AutomatedRegression(
    y=y,
    X=X,
    test_frac = 0.2,
    n_trial=15,
    write_folder='testdir/test4',
    metric_optimise = r2_score,
    metric_assess = [r2_score, median_absolute_error],
    optimisation_direction = 'maximize',
    models_to_optimize=['bayesianridge', 'lassolars',],
    models_to_assess=[ 'lassolars', 'bayesianridge'],
    spline_value={'n_knots': 10, 'degree':3},
    
    )


result4_2 = AutomatedRegression(
    y=y,
    X=X,
    test_frac = 0.2,
    n_trial=30,
    write_folder='testdir/test4',
    metric_optimise = r2_score,
    metric_assess = [r2_score, median_absolute_error],
    optimisation_direction = 'maximize',
    models_to_optimize=['lightgbm', 'catboost',],
    models_to_assess=['lassolars', 'bayesianridge', 'lightgbm', 'catboost',],
    n_weak_models=5
    )

# %%
result4_1.model_hyperoptimise()
result4_2.apply()
# Out:
# [I 2024-01-27 19:32:30,014] A new study created in RDB with name: regression_bayesianridge
# [I 2024-01-27 19:32:30,828] Trial 0 finished with value: 0.6114649964157707 and parameters: {'scaler': 'minmax', 'feature_combo': False, 'max_iter': 32, 'tol': 86.61761457883176, 'alpha_1': 0.010260065124896791, 'alpha_2': 0.12042752972516801, 'lambda_1': 1.6063676259174453e-08, 'lambda_2': 50.01479828856935, 'transformers': None}. Best is trial 0 with value: 0.6114649964157707.
# [I 2024-01-27 19:32:36,195] Trial 1 finished with value: 0.5720784449071958 and parameters: {'scaler': 'robust', 'feature_combo': False, 'max_iter': 249, 'tol': 13.949386073809247, 'alpha_1': 8.345387083873532e-06, 'alpha_2': 4.609124432595992e-05, 'lambda_1': 0.0003636636071695854, 'lambda_2': 0.7108199592296855, 'transformers': 'quantile_trans', 'n_quantiles': 2400}. Best is trial 0 with value: 0.6114649964157707.
# [I 2024-01-27 19:32:53,307] Trial 2 finished with value: 0.261293164123202 and parameters: {'scaler': 'minmax', 'feature_combo': True, 'spline_value': {'degree': 3, 'extrapolation': 'constant', 'include_bias': True, 'knots': 'uniform', 'n_knots': 10, 'order': 'C', 'sparse_output': False}, 'max_iter': 326, 'tol': 30.461376924290935, 'alpha_1': 9.478096804784244e-08, 'alpha_2': 0.06955530592645753, 'lambda_1': 0.0002520721916536751, 'lambda_2': 1.661048634233462e-07, 'transformers': None}. Best is trial 0 with value: 0.6114649964157707.
# [I 2024-01-27 19:32:58,666] Trial 3 pruned.
# [I 2024-01-27 19:33:16,065] Trial 4 finished with value: 0.7002165681369061 and parameters: {'scaler': 'robust', 'feature_combo': True, 'spline_value': {'degree': 3, 'extrapolation': 'constant', 'include_bias': True, 'knots': 'uniform', 'n_knots': 10, 'order': 'C', 'sparse_output': False}, 'max_iter': 149, 'tol': 28.093450975928732, 'alpha_1': 0.0026727653447901085, 'alpha_2': 2.5659149064328484e-07, 'lambda_1': 1.0518887432316704, 'lambda_2': 5.5655288302015325e-08, 'transformers': None}. Best is trial 4 with value: 0.7002165681369061.
# [I 2024-01-27 19:33:21,771] Trial 5 pruned.
# [I 2024-01-27 19:33:27,068] Trial 6 pruned.
# [I 2024-01-27 19:33:38,202] Trial 7 pruned.
# [I 2024-01-27 19:33:48,660] Trial 8 pruned.
# [I 2024-01-27 19:33:54,465] Trial 9 pruned.
# [I 2024-01-27 19:33:55,614] Trial 10 pruned.
# [I 2024-01-27 19:33:55,897] Trial 11 pruned.
# [I 2024-01-27 19:33:56,089] Trial 12 pruned.
# [I 2024-01-27 19:33:56,366] Trial 13 pruned.
# [I 2024-01-27 19:33:56,575] Trial 14 pruned.
# [I 2024-01-27 19:33:56,614] A new study created in RDB with name: regression_lassolars
# [I 2024-01-27 19:33:56,889] Trial 0 finished with value: -0.00021537376071165682 and parameters: {'scaler': 'standard', 'feature_combo': True, 'spline_value': {'degree': 3, 'extrapolation': 'constant', 'include_bias': True, 'knots': 'uniform', 'n_knots': 10, 'order': 'C', 'sparse_output': False}, 'alpha': 12.096475764739722, 'random_state': 42, 'transformers': None}. Best is trial 0 with value: -0.00021537376071165682.
# [I 2024-01-27 19:34:00,069] Trial 1 finished with value: -0.0541832031396249 and parameters: {'scaler': 'minmax', 'feature_combo': False, 'alpha': 0.19149766645100244, 'random_state': 42, 'transformers': 'quantile_trans', 'n_quantiles': 2600}. Best is trial 0 with value: -0.00021537376071165682.
# [I 2024-01-27 19:34:00,263] Trial 2 finished with value: 0.6091221112279888 and parameters: {'scaler': 'standard', 'feature_combo': False, 'alpha': 0.008108292962302002, 'random_state': 42, 'transformers': None}. Best is trial 2 with value: 0.6091221112279888.
# [I 2024-01-27 19:34:00,655] Trial 3 finished with value: -0.054249103987695294 and parameters: {'scaler': 'standard', 'feature_combo': False, 'alpha': 23.296993975101238, 'random_state': 42, 'transformers': 'quantile_trans', 'n_quantiles': 500}. Best is trial 2 with value: 0.6091221112279888.
# [I 2024-01-27 19:34:00,725] Trial 4 pruned.
# [I 2024-01-27 19:34:01,407] Trial 5 finished with value: -0.00021537376071165682 and parameters: {'scaler': 'minmax', 'feature_combo': True, 'spline_value': {'degree': 3, 'extrapolation': 'constant', 'include_bias': True, 'knots': 'uniform', 'n_knots': 10, 'order': 'C', 'sparse_output': False}, 'alpha': 9.356266843604287, 'random_state': 42, 'transformers': None}. Best is trial 2 with value: 0.6091221112279888.
# [I 2024-01-27 19:34:01,568] Trial 6 pruned.
# [I 2024-01-27 19:34:05,740] Trial 7 finished with value: 0.6787676833866643 and parameters: {'scaler': 'standard', 'feature_combo': True, 'spline_value': {'degree': 3, 'extrapolation': 'constant', 'include_bias': True, 'knots': 'uniform', 'n_knots': 10, 'order': 'C', 'sparse_output': False}, 'alpha': 2.3577126571566896e-06, 'random_state': 42, 'transformers': 'quantile_trans', 'n_quantiles': 2600}. Best is trial 7 with value: 0.6787676833866643.
# [I 2024-01-27 19:34:05,850] Trial 8 pruned.
# [I 2024-01-27 19:34:06,051] Trial 9 pruned.
# [I 2024-01-27 19:34:11,199] Trial 10 finished with value: 0.6943249087903088 and parameters: {'scaler': 'robust', 'feature_combo': True, 'spline_value': {'degree': 3, 'extrapolation': 'constant', 'include_bias': True, 'knots': 'uniform', 'n_knots': 10, 'order': 'C', 'sparse_output': False}, 'alpha': 2.799524030450663e-05, 'random_state': 42, 'transformers': 'quantile_trans', 'n_quantiles': 3700}. Best is trial 10 with value: 0.6943249087903088.
# [I 2024-01-27 19:34:15,647] Trial 11 finished with value: 0.6935007726820326 and parameters: {'scaler': 'robust', 'feature_combo': True, 'spline_value': {'degree': 3, 'extrapolation': 'constant', 'include_bias': True, 'knots': 'uniform', 'n_knots': 10, 'order': 'C', 'sparse_output': False}, 'alpha': 6.340083589459202e-05, 'random_state': 42, 'transformers': 'quantile_trans', 'n_quantiles': 3900}. Best is trial 10 with value: 0.6943249087903088.
# [I 2024-01-27 19:34:20,187] Trial 12 finished with value: 0.6932133438329556 and parameters: {'scaler': 'robust', 'feature_combo': True, 'spline_value': {'degree': 3, 'extrapolation': 'constant', 'include_bias': True, 'knots': 'uniform', 'n_knots': 10, 'order': 'C', 'sparse_output': False}, 'alpha': 7.377150247007531e-05, 'random_state': 42, 'transformers': 'quantile_trans', 'n_quantiles': 3900}. Best is trial 10 with value: 0.6943249087903088.
# [I 2024-01-27 19:34:21,681] Trial 13 pruned.
# [I 2024-01-27 19:34:23,390] Trial 14 pruned.
# [I 2024-01-27 19:34:23,433] A new study created in RDB with name: regression_lightgbm
# [I 2024-01-27 19:34:23,780] Trial 0 finished with value: 0.33887207279298215 and parameters: {'scaler': 'minmax', 'objective': 'regression', 'max_depth': 5, 'n_estimators': 88, 'max_bin': 127, 'min_gain_to_split': 14.548647782429915, 'lambda_l1': 0.31044435499483225, 'lambda_l2': 8.148018307012941e-07, 'num_leaves': 48, 'feature_fraction': 0.2650640588680905, 'bagging_fraction': 0.373818018663584, 'bagging_freq': 4, 'min_child_samples': 44, 'random_state': 42, 'verbosity': -1, 'transformers': 'quantile_trans', 'n_quantiles': 600}. Best is trial 0 with value: 0.33887207279298215.
# [I 2024-01-27 19:34:28,551] Trial 1 finished with value: 0.742619314818409 and parameters: {'scaler': 'robust', 'objective': 'regression', 'max_depth': 6, 'n_estimators': 332, 'max_bin': 255, 'min_gain_to_split': 14.233283058799998, 'lambda_l1': 4.905556676028774, 'lambda_l2': 0.18861495878553936, 'num_leaves': 79, 'feature_fraction': 0.1879049026057455, 'bagging_fraction': 0.7158097238609412, 'bagging_freq': 4, 'min_child_samples': 13, 'random_state': 42, 'verbosity': -1, 'transformers': None}. Best is trial 1 with value: 0.742619314818409.
# [I 2024-01-27 19:34:33,767] Trial 2 finished with value: 0.718091693903198 and parameters: {'scaler': None, 'objective': 'regression', 'max_depth': 12, 'n_estimators': 374, 'max_bin': 127, 'min_gain_to_split': 8.968499682166277, 'lambda_l1': 1.9809253750493907, 'lambda_l2': 6.257956190096665e-08, 'num_leaves': 51, 'feature_fraction': 0.14070456001948428, 'bagging_fraction': 0.39279729768693794, 'bagging_freq': 3, 'min_child_samples': 28, 'random_state': 42, 'verbosity': -1, 'transformers': None}. Best is trial 1 with value: 0.742619314818409.
# [I 2024-01-27 19:34:39,629] Trial 3 pruned.
# [I 2024-01-27 19:34:41,157] Trial 4 pruned.
# [I 2024-01-27 19:34:43,329] Trial 5 pruned.
# [I 2024-01-27 19:34:48,244] Trial 6 pruned.
# [I 2024-01-27 19:34:57,516] Trial 7 finished with value: 0.744962006553812 and parameters: {'scaler': 'robust', 'objective': 'regression', 'max_depth': 7, 'n_estimators': 595, 'max_bin': 63, 'min_gain_to_split': 9.50294566141342, 'lambda_l1': 0.000663700518115767, 'lambda_l2': 6.495430353937541e-08, 'num_leaves': 215, 'feature_fraction': 0.3887020584745623, 'bagging_fraction': 0.2678666593598688, 'bagging_freq': 1, 'min_child_samples': 60, 'random_state': 42, 'verbosity': -1, 'transformers': None}. Best is trial 7 with value: 0.744962006553812.
# [I 2024-01-27 19:34:58,313] Trial 8 pruned.
# [I 2024-01-27 19:35:09,966] Trial 9 finished with value: 0.7351576468762188 and parameters: {'scaler': 'robust', 'objective': 'regression', 'max_depth': 18, 'n_estimators': 886, 'max_bin': 511, 'min_gain_to_split': 0.13795577424944472, 'lambda_l1': 8.189245406796203e-08, 'lambda_l2': 0.009365175535873002, 'num_leaves': 3, 'feature_fraction': 0.2447272462757488, 'bagging_fraction': 0.5938604104299275, 'bagging_freq': 5, 'min_child_samples': 66, 'random_state': 42, 'verbosity': -1, 'transformers': 'quantile_trans', 'n_quantiles': 1000}. Best is trial 7 with value: 0.744962006553812.
# [I 2024-01-27 19:35:10,285] Trial 10 pruned.
# [I 2024-01-27 19:35:16,291] Trial 11 finished with value: 0.7758732450546485 and parameters: {'scaler': 'robust', 'objective': 'regression', 'max_depth': 8, 'n_estimators': 298, 'max_bin': 255, 'min_gain_to_split': 11.293120676899584, 'lambda_l1': 0.0019644136893157776, 'lambda_l2': 3.1625804313819863, 'num_leaves': 157, 'feature_fraction': 0.4111243707234399, 'bagging_fraction': 0.8005630538517242, 'bagging_freq': 1, 'min_child_samples': 8, 'random_state': 42, 'verbosity': -1, 'transformers': None}. Best is trial 11 with value: 0.7758732450546485.
# [I 2024-01-27 19:35:21,056] Trial 12 finished with value: 0.770987794547503 and parameters: {'scaler': 'robust', 'objective': 'regression', 'max_depth': 9, 'n_estimators': 170, 'max_bin': 255, 'min_gain_to_split': 10.96366953455124, 'lambda_l1': 0.0012708072185779076, 'lambda_l2': 1.082697080026957e-05, 'num_leaves': 171, 'feature_fraction': 0.4608603727138396, 'bagging_fraction': 0.9977741027932155, 'bagging_freq': 1, 'min_child_samples': 2, 'random_state': 42, 'verbosity': -1, 'transformers': None}. Best is trial 11 with value: 0.7758732450546485.
# [I 2024-01-27 19:35:23,679] Trial 13 pruned.
# [I 2024-01-27 19:35:28,760] Trial 14 finished with value: 0.80659813920528 and parameters: {'scaler': 'robust', 'objective': 'regression', 'max_depth': 8, 'n_estimators': 149, 'max_bin': 255, 'min_gain_to_split': 5.343402703558767, 'lambda_l1': 0.01146690242205455, 'lambda_l2': 1.85422218946809e-05, 'num_leaves': 152, 'feature_fraction': 0.7497509325046324, 'bagging_fraction': 0.8017199671574651, 'bagging_freq': 2, 'min_child_samples': 22, 'random_state': 42, 'verbosity': -1, 'transformers': None}. Best is trial 14 with value: 0.80659813920528.
# [I 2024-01-27 19:35:33,561] Trial 15 finished with value: 0.8025936885149978 and parameters: {'scaler': 'robust', 'objective': 'regression', 'max_depth': 12, 'n_estimators': 109, 'max_bin': 255, 'min_gain_to_split': 5.03343246030939, 'lambda_l1': 0.045116268443092473, 'lambda_l2': 0.0004101389966286217, 'num_leaves': 126, 'feature_fraction': 0.8162809857042157, 'bagging_fraction': 0.7446520079101321, 'bagging_freq': 2, 'min_child_samples': 22, 'random_state': 42, 'verbosity': -1, 'transformers': None}. Best is trial 14 with value: 0.80659813920528.
# [I 2024-01-27 19:35:39,079] Trial 16 finished with value: 0.8163501081700486 and parameters: {'scaler': 'robust', 'objective': 'regression', 'max_depth': 12, 'n_estimators': 97, 'max_bin': 255, 'min_gain_to_split': 3.690966263457245, 'lambda_l1': 0.03326230958567514, 'lambda_l2': 0.00010195140261918181, 'num_leaves': 126, 'feature_fraction': 0.8059473563805308, 'bagging_fraction': 0.7510663518334906, 'bagging_freq': 2, 'min_child_samples': 25, 'random_state': 42, 'verbosity': -1, 'transformers': None}. Best is trial 16 with value: 0.8163501081700486.
# [I 2024-01-27 19:35:44,623] Trial 17 finished with value: 0.8201862754708573 and parameters: {'scaler': None, 'objective': 'regression', 'max_depth': 15, 'n_estimators': 50, 'max_bin': 255, 'min_gain_to_split': 2.0267298761430794, 'lambda_l1': 0.01052160952889829, 'lambda_l2': 1.406353943041419e-05, 'num_leaves': 116, 'feature_fraction': 0.7765534997227992, 'bagging_fraction': 0.6698746761139318, 'bagging_freq': 2, 'min_child_samples': 42, 'random_state': 42, 'verbosity': -1, 'transformers': None}. Best is trial 17 with value: 0.8201862754708573.
# [I 2024-01-27 19:35:47,201] Trial 18 pruned.
# [I 2024-01-27 19:35:49,148] Trial 19 pruned.
# [I 2024-01-27 19:35:57,601] Trial 20 finished with value: 0.8334800491616676 and parameters: {'scaler': None, 'objective': 'regression', 'max_depth': 17, 'n_estimators': 76, 'max_bin': 1023, 'min_gain_to_split': 0.6501608702994321, 'lambda_l1': 0.9190100017950755, 'lambda_l2': 0.0035899380190408223, 'num_leaves': 112, 'feature_fraction': 0.6439436073018239, 'bagging_fraction': 0.4951177851913956, 'bagging_freq': 2, 'min_child_samples': 39, 'random_state': 42, 'verbosity': -1, 'transformers': None}. Best is trial 20 with value: 0.8334800491616676.
# [I 2024-01-27 19:36:14,645] Trial 21 finished with value: 0.8415432842992076 and parameters: {'scaler': None, 'objective': 'regression', 'max_depth': 17, 'n_estimators': 70, 'max_bin': 1023, 'min_gain_to_split': 0.0412737279498927, 'lambda_l1': 0.7477762923347034, 'lambda_l2': 0.005456483297069993, 'num_leaves': 116, 'feature_fraction': 0.6585776215740602, 'bagging_fraction': 0.5104918224087684, 'bagging_freq': 2, 'min_child_samples': 38, 'random_state': 42, 'verbosity': -1, 'transformers': None}. Best is trial 21 with value: 0.8415432842992076.
# [I 2024-01-27 19:36:29,648] Trial 22 finished with value: 0.8391150687679229 and parameters: {'scaler': None, 'objective': 'regression', 'max_depth': 17, 'n_estimators': 65, 'max_bin': 1023, 'min_gain_to_split': 0.024101678017516504, 'lambda_l1': 0.9644579210910487, 'lambda_l2': 0.0257087741187123, 'num_leaves': 105, 'feature_fraction': 0.6000887236176704, 'bagging_fraction': 0.48372452571492375, 'bagging_freq': 3, 'min_child_samples': 37, 'random_state': 42, 'verbosity': -1, 'transformers': None}. Best is trial 21 with value: 0.8415432842992076.
# [I 2024-01-27 19:36:43,541] Trial 23 finished with value: 0.8394192643672964 and parameters: {'scaler': None, 'objective': 'regression', 'max_depth': 20, 'n_estimators': 80, 'max_bin': 1023, 'min_gain_to_split': 0.12478878494381343, 'lambda_l1': 1.0586282433534255, 'lambda_l2': 0.013192758239714789, 'num_leaves': 53, 'feature_fraction': 0.5993060885364823, 'bagging_fraction': 0.4892025281183124, 'bagging_freq': 3, 'min_child_samples': 38, 'random_state': 42, 'verbosity': -1, 'transformers': None}. Best is trial 21 with value: 0.8415432842992076.
# [I 2024-01-27 19:36:44,643] Trial 24 pruned.
# [I 2024-01-27 19:36:47,491] Trial 25 pruned.
# [I 2024-01-27 19:36:55,845] Trial 26 finished with value: 0.8270620888063999 and parameters: {'scaler': None, 'objective': 'regression', 'max_depth': 18, 'n_estimators': 66, 'max_bin': 1023, 'min_gain_to_split': 0.255112325820948, 'lambda_l1': 8.174357372264392, 'lambda_l2': 0.014055730194256828, 'num_leaves': 98, 'feature_fraction': 0.6646853097232163, 'bagging_fraction': 0.5684221862481948, 'bagging_freq': 3, 'min_child_samples': 17, 'random_state': 42, 'verbosity': -1, 'transformers': None}. Best is trial 21 with value: 0.8415432842992076.
# [I 2024-01-27 19:36:56,555] Trial 27 pruned.
# [I 2024-01-27 19:36:57,844] Trial 28 pruned.
# [I 2024-01-27 19:36:58,660] Trial 29 pruned.
# [I 2024-01-27 19:36:58,693] A new study created in RDB with name: regression_catboost
# [I 2024-01-27 19:36:59,490] Trial 0 finished with value: 0.24222367011515916 and parameters: {'scaler': 'robust', 'depth': 7, 'iterations': 109, 'learning_rate': 0.008213314538191411, 'l2_leaf_reg': 0.12680822080429408, 'rsm': 0.2725503440049082, 'logging_level': 'Silent', 'random_seed': 42, 'transformers': 'quantile_trans', 'n_quantiles': 1600}. Best is trial 0 with value: 0.24222367011515916.
# [I 2024-01-27 19:37:01,869] Trial 1 finished with value: 0.34122199287254895 and parameters: {'scaler': None, 'depth': 6, 'iterations': 86, 'learning_rate': 0.014067922777716855, 'l2_leaf_reg': 1.4701320504898967, 'rsm': 0.28796463881644724, 'logging_level': 'Silent', 'random_seed': 42, 'transformers': 'quantile_trans', 'n_quantiles': 800}. Best is trial 1 with value: 0.34122199287254895.
# [I 2024-01-27 19:37:06,111] Trial 2 finished with value: 0.6140611456116806 and parameters: {'scaler': 'minmax', 'depth': 1, 'iterations': 397, 'learning_rate': 0.019255395572015603, 'l2_leaf_reg': 7.942632291801132, 'rsm': 0.9639837773183603, 'logging_level': 'Silent', 'random_seed': 42, 'transformers': None}. Best is trial 2 with value: 0.6140611456116806.
# [I 2024-01-27 19:37:09,855] Trial 3 finished with value: 0.7635211715354538 and parameters: {'scaler': 'minmax', 'depth': 6, 'iterations': 330, 'learning_rate': 0.19978158040350072, 'l2_leaf_reg': 0.5130781383387442, 'rsm': 0.10620472883306084, 'logging_level': 'Silent', 'random_seed': 42, 'transformers': 'quantile_trans', 'n_quantiles': 600}. Best is trial 3 with value: 0.7635211715354538.
# [I 2024-01-27 19:37:14,358] Trial 4 finished with value: 0.6189379029751463 and parameters: {'scaler': 'minmax', 'depth': 8, 'iterations': 52, 'learning_rate': 0.03865304288032152, 'l2_leaf_reg': 2.6796832798314654, 'rsm': 0.812012260732389, 'logging_level': 'Silent', 'random_seed': 42, 'transformers': 'quantile_trans', 'n_quantiles': 2100}. Best is trial 3 with value: 0.7635211715354538.
# [I 2024-01-27 19:37:14,891] Trial 5 pruned.
# [I 2024-01-27 19:37:15,153] Trial 6 pruned.
# [I 2024-01-27 19:37:19,175] Trial 7 finished with value: 0.8084217837815583 and parameters: {'scaler': None, 'depth': 6, 'iterations': 134, 'learning_rate': 0.2342760768678983, 'l2_leaf_reg': 8.463621602561947, 'rsm': 0.5211373448181834, 'logging_level': 'Silent', 'random_seed': 42, 'transformers': 'quantile_trans', 'n_quantiles': 1100}. Best is trial 7 with value: 0.8084217837815583.
# [I 2024-01-27 19:37:21,405] Trial 8 pruned.
# [I 2024-01-27 19:37:24,542] Trial 9 finished with value: 0.7699953645398957 and parameters: {'scaler': 'standard', 'depth': 6, 'iterations': 124, 'learning_rate': 0.0461830205604933, 'l2_leaf_reg': 0.055359603190836125, 'rsm': 0.362412951864749, 'logging_level': 'Silent', 'random_seed': 42, 'transformers': None}. Best is trial 7 with value: 0.8084217837815583.
# [I 2024-01-27 19:37:24,753] Trial 10 pruned.
# [I 2024-01-27 19:37:28,760] Trial 11 finished with value: 0.8188915282579897 and parameters: {'scaler': 'standard', 'depth': 5, 'iterations': 181, 'learning_rate': 0.9943375704062065, 'l2_leaf_reg': 9.825123906848974, 'rsm': 0.4855178194264056, 'logging_level': 'Silent', 'random_seed': 42, 'transformers': None}. Best is trial 11 with value: 0.8188915282579897.
# [I 2024-01-27 19:37:32,890] Trial 12 finished with value: 0.8208349824693861 and parameters: {'scaler': 'standard', 'depth': 4, 'iterations': 218, 'learning_rate': 0.9368131535692534, 'l2_leaf_reg': 8.64787189174839, 'rsm': 0.54551835275588, 'logging_level': 'Silent', 'random_seed': 42, 'transformers': None}. Best is trial 12 with value: 0.8208349824693861.
# [I 2024-01-27 19:37:37,220] Trial 13 finished with value: 0.8215317274281316 and parameters: {'scaler': 'standard', 'depth': 4, 'iterations': 225, 'learning_rate': 0.9310433350609741, 'l2_leaf_reg': 2.6239621107584954, 'rsm': 0.6506164158463197, 'logging_level': 'Silent', 'random_seed': 42, 'transformers': None}. Best is trial 13 with value: 0.8215317274281316.
# [I 2024-01-27 19:37:39,682] Trial 14 pruned.
# [I 2024-01-27 19:37:47,258] Trial 15 finished with value: 0.8350066419346586 and parameters: {'scaler': 'standard', 'depth': 3, 'iterations': 484, 'learning_rate': 0.4627694672548403, 'l2_leaf_reg': 0.6440912390122551, 'rsm': 0.7412377322624407, 'logging_level': 'Silent', 'random_seed': 42, 'transformers': None}. Best is trial 15 with value: 0.8350066419346586.
# [I 2024-01-27 19:37:54,316] Trial 16 finished with value: 0.835308579372448 and parameters: {'scaler': 'standard', 'depth': 3, 'iterations': 439, 'learning_rate': 0.4089287445767974, 'l2_leaf_reg': 0.5342724633189248, 'rsm': 0.7868563382113142, 'logging_level': 'Silent', 'random_seed': 42, 'transformers': None}. Best is trial 16 with value: 0.835308579372448.
# [I 2024-01-27 19:38:00,590] Trial 17 finished with value: 0.8041656619211075 and parameters: {'scaler': 'standard', 'depth': 2, 'iterations': 474, 'learning_rate': 0.11105492768223384, 'l2_leaf_reg': 0.50494105445483, 'rsm': 0.831906665922389, 'logging_level': 'Silent', 'random_seed': 42, 'transformers': None}. Best is trial 16 with value: 0.835308579372448.
# [I 2024-01-27 19:38:05,525] Trial 18 finished with value: 0.8219965837209315 and parameters: {'scaler': 'standard', 'depth': 2, 'iterations': 365, 'learning_rate': 0.3577763841466064, 'l2_leaf_reg': 0.8555216545713412, 'rsm': 0.9580114661143468, 'logging_level': 'Silent', 'random_seed': 42, 'transformers': None}. Best is trial 16 with value: 0.835308579372448.
# [I 2024-01-27 19:38:10,577] Trial 19 finished with value: 0.816525269148816 and parameters: {'scaler': 'standard', 'depth': 3, 'iterations': 314, 'learning_rate': 0.11495407836692137, 'l2_leaf_reg': 0.28851597316473465, 'rsm': 0.7570136693806095, 'logging_level': 'Silent', 'random_seed': 42, 'transformers': None}. Best is trial 16 with value: 0.835308579372448.
# [I 2024-01-27 19:38:14,716] Trial 20 pruned.
# [I 2024-01-27 19:38:19,139] Trial 21 finished with value: 0.8209308930020274 and parameters: {'scaler': 'standard', 'depth': 2, 'iterations': 324, 'learning_rate': 0.4458281948504248, 'l2_leaf_reg': 1.013258578006292, 'rsm': 0.9881190334232965, 'logging_level': 'Silent', 'random_seed': 42, 'transformers': None}. Best is trial 16 with value: 0.835308579372448.
# [I 2024-01-27 19:38:24,232] Trial 22 finished with value: 0.823852021223219 and parameters: {'scaler': 'standard', 'depth': 2, 'iterations': 376, 'learning_rate': 0.42765438208326706, 'l2_leaf_reg': 0.7983513886914144, 'rsm': 0.9059495865639762, 'logging_level': 'Silent', 'random_seed': 42, 'transformers': None}. Best is trial 16 with value: 0.835308579372448.
# [I 2024-01-27 19:38:25,238] Trial 23 pruned.
# [I 2024-01-27 19:38:26,735] Trial 24 pruned.
# [I 2024-01-27 19:38:33,434] Trial 25 finished with value: 0.8387736201690977 and parameters: {'scaler': 'standard', 'depth': 5, 'iterations': 282, 'learning_rate': 0.5054767457195204, 'l2_leaf_reg': 4.021784866127178, 'rsm': 0.9139660921079324, 'logging_level': 'Silent', 'random_seed': 42, 'transformers': None}. Best is trial 25 with value: 0.8387736201690977.
# [I 2024-01-27 19:38:39,660] Trial 26 finished with value: 0.8388634345710473 and parameters: {'scaler': 'standard', 'depth': 5, 'iterations': 275, 'learning_rate': 0.20492278448878434, 'l2_leaf_reg': 4.058435689698043, 'rsm': 0.6543022221569896, 'logging_level': 'Silent', 'random_seed': 42, 'transformers': None}. Best is trial 26 with value: 0.8388634345710473.
# [I 2024-01-27 19:38:46,155] Trial 27 finished with value: 0.8383924116954729 and parameters: {'scaler': 'robust', 'depth': 5, 'iterations': 282, 'learning_rate': 0.16920200430514418, 'l2_leaf_reg': 4.018405740112174, 'rsm': 0.6632211065201163, 'logging_level': 'Silent', 'random_seed': 42, 'transformers': None}. Best is trial 26 with value: 0.8388634345710473.
# [I 2024-01-27 19:38:47,329] Trial 28 pruned.
# [I 2024-01-27 19:38:49,835] Trial 29 pruned.
# [I 2024-01-27 19:38:49,846] Using an existing study with name 'regression_lassolars' instead of creating a new one.
# /Users/opodriscoll/miniconda3/envs/to_delete/lib/python3.11/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains {'degree': 3, 'extrapolation': 'constant', 'include_bias': True, 'knots': 'uniform', 'n_knots': 10, 'order': 'C', 'sparse_output': False} which is of type dict.
#   warnings.warn(message)
# [I 2024-01-27 19:38:49,875] Using an existing study with name 'regression_bayesianridge' instead of creating a new one.
# Number of unique weak models less than requested number of weak models: 3 < 5
# n_weak_models set to total number of weak models instead.
# /Users/opodriscoll/miniconda3/envs/to_delete/lib/python3.11/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains {'degree': 3, 'extrapolation': 'constant', 'include_bias': True, 'knots': 'uniform', 'n_knots': 10, 'order': 'C', 'sparse_output': False} which is of type dict.
#   warnings.warn(message)
# [I 2024-01-27 19:38:49,907] Using an existing study with name 'regression_lightgbm' instead of creating a new one.
# [I 2024-01-27 19:38:49,952] Using an existing study with name 'regression_catboost' instead of creating a new one.

# %%
pprint.pprint(result4_2.summary)
plt.scatter(result4_2.y_pred, result4_2.y_test, s = 0.5); plt.plot([0,5], [0,5], '--k'); 
plt.xlabel("Prediction"); _ = plt.ylabel("Validation")
# Out:
# {'bayesianridge_0': [[0.574648684778255, 0.04491854111867346],
#                      [0.4118712015771207, 0.017609952450281043]],
#  'bayesianridge_1': [[0.5499583665812334, 0.016469258007420332],
#                      [0.3647563927708298, 0.007060951395038324]],
#  'bayesianridge_2': [[0.639288152525258, 0.07935482921565686],
#                      [0.3356755714271468, 0.01047799389840974]],
#  'bayesianridge_best': [[0.6166525801393758, 0.11977394809151548],
#                         [0.33962362540388663, 0.008000757012443576]],
#  'catboost_0': [[0.24247032784552286, 0.007822135311264957],
#                 [0.5279693739204923, 0.007955560254737284]],
#  'catboost_11': [[0.813585775356044, 0.02752954038556353],
#                  [0.225545626327827, 0.008704856897068756]],
#  'catboost_12': [[0.8234159838821539, 0.024344352131895487],
#                  [0.2240167642756668, 0.008039283325598976]],
#  'catboost_27': [[0.8345526239813836, 0.022240927510289943],
#                  [0.20500696647203692, 0.007938829237138787]],
#  'catboost_3': [[0.7513314678550758, 0.021753738925867783],
#                 [0.2484142430738189, 0.007725015486728221]],
#  'catboost_best': [[0.8335942087789722, 0.020877666059635085],
#                    [0.2009068782784929, 0.00925004067972444]],
#  'lassolars_0': [[-0.0007957517926284741, 0.0008177019377945391],
#                  [0.7586575499031007, 0.025822381370999646]],
#  'lassolars_1': [[-0.05094270029488994, 0.01064107709238286],
#                  [0.6769151044795765, 0.0068311616372136105]],
#  'lassolars_12': [[0.6709042160849783, 0.011220104923471903],
#                   [0.30480254965418546, 0.002897402497707528]],
#  'lassolars_2': [[0.5803246918518472, 0.029622316889292673],
#                  [0.4130619851808441, 0.015543537764640717]],
#  'lassolars_7': [[0.6548792139545462, 0.018608405994477904],
#                  [0.3101030987375952, 0.006318461547672059]],
#  'lassolars_best': [[0.6719954270654892, 0.011698182551050441],
#                     [0.30423266386889913, 0.0038402405087859795]],
#  'lightgbm_0': [[0.36945485668139344, 0.00884997745789735],
#                 [0.4675331797325321, 0.01068022692023164]],
#  'lightgbm_1': [[0.7408341464359194, 0.022959606514820395],
#                 [0.29277524719619097, 0.009383812464360724]],
#  'lightgbm_17': [[0.8194924447718327, 0.022853829424530705],
#                  [0.2119963491965112, 0.013622687075425738]],
#  'lightgbm_20': [[0.8316950303259374, 0.023420949912043562],
#                  [0.20607629992847404, 0.013780374130494474]],
#  'lightgbm_9': [[0.7238521989633873, 0.02577314974376235],
#                 [0.2654395273023629, 0.007410669359320296]],
#  'lightgbm_best': [[0.842465144726828, 0.023183275415617457],
#                    [0.1905571414709165, 0.006592188424673432]],
#  'stacked': [[0.8518708807758172, 0.022068211670996207],
#              [0.1855798132913567, 0.006138420521802015]]}

# %% [markdown]
# Performance greatly increases when including the boosted models. Boosted models are generally more capable on non-linear datasets, even when supporting the latter by spline transformations. Linear models require more pre-processing in order to get their performance on the same level as the boosted methods. The enhanced diversity between models enables the `stacked` regression to outperform all other individual regressors.

# %% [markdown]
# ## Regression #5: continue model training
# Say we suspect the increased performance of the boosted models to be caused by training them for more trials than the linear models, then it would be desireable to perform an equal number of trials for all models. Here we reload the linear models and train them for an additional 15 trials up to a maximum of 30 trials total. In order to do so we specify the same write folder as during the previous optimisation. Since `lightgbm` and `catboost` already exist in this folder, they need not be re-optimized in order to be assessed.

# %%
result5 = AutomatedRegression(
    y=y,
    X=X,
    test_frac = 0.2,
    n_trial=15,
    write_folder='testdir/test4',
    metric_optimise = r2_score,
    metric_assess = [r2_score, median_absolute_error],
    optimisation_direction = 'maximize',
    models_to_optimize=['bayesianridge', 'lassolars',],
    models_to_assess=[ 'lassolars', 'bayesianridge', 'lightgbm', 'catboost'],
    spline_value={'n_knots': 10, 'degree':3},
    reload_study=True,
    reload_trial_cap=30,
    n_weak_models=5,
    )

# %%
result5.apply()
# Out:
# [I 2024-01-27 19:39:41,266] Using an existing study with name 'regression_bayesianridge' instead of creating a new one.
# [I 2024-01-27 19:39:42,428] Trial 15 pruned.
# [I 2024-01-27 19:39:58,919] Trial 16 finished with value: 0.6780904557152664 and parameters: {'scaler': None, 'feature_combo': True, 'spline_value': {'degree': 3, 'extrapolation': 'constant', 'include_bias': True, 'knots': 'uniform', 'n_knots': 10, 'order': 'C', 'sparse_output': False}, 'max_iter': 228, 'tol': 61.193162770991165, 'alpha_1': 54.91605619119651, 'alpha_2': 1.0461598792590998, 'lambda_1': 0.01567976073662828, 'lambda_2': 5.5119446470928086e-08, 'transformers': None}. Best is trial 4 with value: 0.7002165681369061.
# [I 2024-01-27 19:40:15,814] Trial 17 finished with value: 0.678059102618417 and parameters: {'scaler': None, 'feature_combo': True, 'spline_value': {'degree': 3, 'extrapolation': 'constant', 'include_bias': True, 'knots': 'uniform', 'n_knots': 10, 'order': 'C', 'sparse_output': False}, 'max_iter': 246, 'tol': 68.07834868106548, 'alpha_1': 89.3378900247618, 'alpha_2': 3.4807832853830696e-07, 'lambda_1': 0.102713127673829, 'lambda_2': 2.1669996907627554e-08, 'transformers': None}. Best is trial 4 with value: 0.7002165681369061.
# [I 2024-01-27 19:40:21,060] Trial 18 pruned.
# [I 2024-01-27 19:40:38,685] Trial 19 finished with value: 0.6315729922097868 and parameters: {'scaler': None, 'feature_combo': True, 'spline_value': {'degree': 3, 'extrapolation': 'constant', 'include_bias': True, 'knots': 'uniform', 'n_knots': 10, 'order': 'C', 'sparse_output': False}, 'max_iter': 399, 'tol': 9.88554045473779, 'alpha_1': 7.831659965571792e-06, 'alpha_2': 43.3136570672554, 'lambda_1': 0.016135870079161747, 'lambda_2': 1.0764440862286277e-07, 'transformers': None}. Best is trial 4 with value: 0.7002165681369061.
# [I 2024-01-27 19:40:44,266] Trial 20 pruned.
# [I 2024-01-27 19:40:55,280] Trial 21 pruned.
# [I 2024-01-27 19:41:11,413] Trial 22 finished with value: 0.6780197309246799 and parameters: {'scaler': None, 'feature_combo': True, 'spline_value': {'degree': 3, 'extrapolation': 'constant', 'include_bias': True, 'knots': 'uniform', 'n_knots': 10, 'order': 'C', 'sparse_output': False}, 'max_iter': 170, 'tol': 62.819942181342554, 'alpha_1': 96.4660763393655, 'alpha_2': 4.370743896485755e-07, 'lambda_1': 0.009609772079808758, 'lambda_2': 1.19752487751672e-07, 'transformers': None}. Best is trial 4 with value: 0.7002165681369061.
# [I 2024-01-27 19:41:16,951] Trial 23 pruned.
# [I 2024-01-27 19:41:22,323] Trial 24 pruned.
# [I 2024-01-27 19:41:33,712] Trial 25 pruned.
# [I 2024-01-27 19:41:39,513] Trial 26 pruned.
# [I 2024-01-27 19:41:56,343] Trial 27 finished with value: 0.6786156899125211 and parameters: {'scaler': None, 'feature_combo': True, 'spline_value': {'degree': 3, 'extrapolation': 'constant', 'include_bias': True, 'knots': 'uniform', 'n_knots': 10, 'order': 'C', 'sparse_output': False}, 'max_iter': 242, 'tol': 60.18995752199415, 'alpha_1': 0.10144355182928354, 'alpha_2': 8.989027405968906e-06, 'lambda_1': 1.3619920594062396, 'lambda_2': 2.284487836282807e-06, 'transformers': None}. Best is trial 4 with value: 0.7002165681369061.
# [I 2024-01-27 19:42:07,598] Trial 28 pruned.
# [I 2024-01-27 19:42:24,029] Trial 29 finished with value: 0.10293755906933551 and parameters: {'scaler': 'standard', 'feature_combo': True, 'spline_value': {'degree': 3, 'extrapolation': 'constant', 'include_bias': True, 'knots': 'uniform', 'n_knots': 10, 'order': 'C', 'sparse_output': False}, 'max_iter': 182, 'tol': 48.522813367455775, 'alpha_1': 0.0017291206392467929, 'alpha_2': 2.0267903228020203, 'lambda_1': 15.704825097251227, 'lambda_2': 8.833157483462051e-05, 'transformers': None}. Best is trial 4 with value: 0.7002165681369061.
# [I 2024-01-27 19:42:24,054] Using an existing study with name 'regression_lassolars' instead of creating a new one.
# [I 2024-01-27 19:42:25,983] Trial 15 finished with value: 0.6927682892026887 and parameters: {'scaler': 'robust', 'feature_combo': True, 'spline_value': {'degree': 3, 'extrapolation': 'constant', 'include_bias': True, 'knots': 'uniform', 'n_knots': 10, 'order': 'C', 'sparse_output': False}, 'alpha': 9.540932917872877e-05, 'random_state': 42, 'transformers': 'quantile_trans', 'n_quantiles': 1300}. Best is trial 10 with value: 0.6943249087903088.
# [I 2024-01-27 19:42:27,426] Trial 16 pruned.
# [I 2024-01-27 19:42:28,880] Trial 17 pruned.
# [I 2024-01-27 19:42:29,259] Trial 18 pruned.
# [I 2024-01-27 19:42:30,358] Trial 19 pruned.
# [I 2024-01-27 19:42:31,857] Trial 20 pruned.
# [I 2024-01-27 19:42:36,518] Trial 21 finished with value: 0.694501179111546 and parameters: {'scaler': 'robust', 'feature_combo': True, 'spline_value': {'degree': 3, 'extrapolation': 'constant', 'include_bias': True, 'knots': 'uniform', 'n_knots': 10, 'order': 'C', 'sparse_output': False}, 'alpha': 2.4862107059749832e-05, 'random_state': 42, 'transformers': 'quantile_trans', 'n_quantiles': 4000}. Best is trial 21 with value: 0.694501179111546.
# [I 2024-01-27 19:42:38,110] Trial 22 pruned.
# [I 2024-01-27 19:42:39,583] Trial 23 pruned.
# [I 2024-01-27 19:42:44,001] Trial 24 finished with value: 0.6953392361801234 and parameters: {'scaler': 'robust', 'feature_combo': True, 'spline_value': {'degree': 3, 'extrapolation': 'constant', 'include_bias': True, 'knots': 'uniform', 'n_knots': 10, 'order': 'C', 'sparse_output': False}, 'alpha': 1.4105664817129856e-05, 'random_state': 42, 'transformers': 'quantile_trans', 'n_quantiles': 3500}. Best is trial 24 with value: 0.6953392361801234.
# [I 2024-01-27 19:42:48,580] Trial 25 finished with value: 0.6950793641478595 and parameters: {'scaler': 'robust', 'feature_combo': True, 'spline_value': {'degree': 3, 'extrapolation': 'constant', 'include_bias': True, 'knots': 'uniform', 'n_knots': 10, 'order': 'C', 'sparse_output': False}, 'alpha': 1.7815465962441996e-05, 'random_state': 42, 'transformers': 'quantile_trans', 'n_quantiles': 3500}. Best is trial 24 with value: 0.6953392361801234.
# [I 2024-01-27 19:42:50,236] Trial 26 pruned.
# [I 2024-01-27 19:42:51,427] Trial 27 pruned.
# [I 2024-01-27 19:42:51,752] Trial 28 pruned.
# [I 2024-01-27 19:42:51,980] Trial 29 pruned.
# [I 2024-01-27 19:42:51,998] Using an existing study with name 'regression_lassolars' instead of creating a new one.
# /Users/opodriscoll/miniconda3/envs/to_delete/lib/python3.11/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains {'degree': 3, 'extrapolation': 'constant', 'include_bias': True, 'knots': 'uniform', 'n_knots': 10, 'order': 'C', 'sparse_output': False} which is of type dict.
#   warnings.warn(message)
# [I 2024-01-27 19:42:52,061] Using an existing study with name 'regression_bayesianridge' instead of creating a new one.
# /Users/opodriscoll/miniconda3/envs/to_delete/lib/python3.11/site-packages/optuna/distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains {'degree': 3, 'extrapolation': 'constant', 'include_bias': True, 'knots': 'uniform', 'n_knots': 10, 'order': 'C', 'sparse_output': False} which is of type dict.
#   warnings.warn(message)
# [I 2024-01-27 19:42:52,127] Using an existing study with name 'regression_lightgbm' instead of creating a new one.
# [I 2024-01-27 19:42:52,203] Using an existing study with name 'regression_catboost' instead of creating a new one.
# _________________________
# Stacked model overwritten
# _________________________

# %%
pprint.pprint(result5.summary)
plt.scatter(result5.y_pred, result5.y_test, s = 0.5); plt.plot([0,5], [0,5], '--k'); 
plt.xlabel("Prediction"); _ = plt.ylabel("Validation")
# Out:
# {'bayesianridge_0': [[0.574648684778255, 0.04491854111867346],
#                      [0.4118712015771207, 0.017609952450281043]],
#  'bayesianridge_1': [[0.5499583665812334, 0.016469258007420332],
#                      [0.3647563927708298, 0.007060951395038324]],
#  'bayesianridge_19': [[0.6352755958480747, 0.08825810020232602],
#                       [0.33617974925429733, 0.010555511827439542]],
#  'bayesianridge_2': [[0.639288152525258, 0.07935482921565686],
#                      [0.3356755714271468, 0.01047799389840974]],
#  'bayesianridge_29': [[0.6282930936416442, 0.0965784371012702],
#                       [0.3370404164355323, 0.009886305931806299]],
#  'bayesianridge_best': [[0.6166525801393758, 0.11977394809151548],
#                         [0.33962362540388663, 0.008000757012443576]],
#  'catboost_0': [[0.24247032784552286, 0.007822135311264957],
#                 [0.5279693739204923, 0.007955560254737284]],
#  'catboost_11': [[0.813585775356044, 0.02752954038556353],
#                  [0.225545626327827, 0.008704856897068756]],
#  'catboost_12': [[0.8234159838821539, 0.024344352131895487],
#                  [0.2240167642756668, 0.008039283325598976]],
#  'catboost_27': [[0.8345526239813836, 0.022240927510289943],
#                  [0.20500696647203692, 0.007938829237138787]],
#  'catboost_3': [[0.7513314678550758, 0.021753738925867783],
#                 [0.2484142430738189, 0.007725015486728221]],
#  'catboost_best': [[0.8335942087789722, 0.020877666059635085],
#                    [0.2009068782784929, 0.00925004067972444]],
#  'lassolars_0': [[-0.0007957517926284741, 0.0008177019377945391],
#                  [0.7586575499031007, 0.025822381370999646]],
#  'lassolars_1': [[-0.05094270029488994, 0.01064107709238286],
#                  [0.6769151044795765, 0.0068311616372136105]],
#  'lassolars_21': [[0.6721322268222869, 0.011745595734939393],
#                   [0.30414804232776693, 0.004134939718900749]],
#  'lassolars_3': [[-0.050752448239698246, 0.010621798465932114],
#                  [0.6771091433498123, 0.006947970443418772]],
#  'lassolars_5': [[-0.0007957517926284741, 0.0008177019377945391],
#                  [0.7586575499031007, 0.025822381370999646]],
#  'lassolars_best': [[0.6726632803573787, 0.01237619210030143],
#                     [0.3017937639072337, 0.004704596638994221]],
#  'lightgbm_0': [[0.36945485668139344, 0.00884997745789735],
#                 [0.4675331797325321, 0.01068022692023164]],
#  'lightgbm_1': [[0.7408341464359194, 0.022959606514820395],
#                 [0.29277524719619097, 0.009383812464360724]],
#  'lightgbm_17': [[0.8194924447718327, 0.022853829424530705],
#                  [0.2119963491965112, 0.013622687075425738]],
#  'lightgbm_20': [[0.8316950303259374, 0.023420949912043562],
#                  [0.20607629992847404, 0.013780374130494474]],
#  'lightgbm_9': [[0.7238521989633873, 0.02577314974376235],
#                 [0.2654395273023629, 0.007410669359320296]],
#  'lightgbm_best': [[0.842465144726828, 0.023183275415617457],
#                    [0.1905571414709165, 0.006592188424673432]],
#  'stacked': [[0.8514713729735328, 0.0219980975261625],
#              [0.1851111686568973, 0.006153730925418793]]}

# %% [markdown]
# As we had already trained a final stacked regressor in the `test4` directory, we are asked whether or not to overwrite the previous save of the stacked model with the new model.
#
# Performance for the boosted models remains the same (as they are not trained) but for the linear models it changes ever so slightly. However, the additional 15 trials for the linear models have little effect, confirming that the additional training was not the root cause of improvement of the boosted methods over the linear methods.
#
# Further improvements to the current predictions can be made by increasing the number of trials, including more regression methods and of course smart feature engineering or outlier removal prior to applying the regression. There are several unused hyperparamters of the `AutomatedRegression` class which may enhance performance, such as `boosted_early_stopping_rounds` for non-sklearn boosted methods (`lightgbm`, `catboost`, `xgboost`) and `nominal_columns` & `ordinal_columns` when categorical data is included

# %% [markdown]
# ## Regression #6: multithreading
# The optimization package `optuna` allows for multithreaded optimization. This can greatly increase the optimization speed. However, when different models are trained simoultaneously, they will be unable to include optimization information of other ongoing training processes. For instance, if `n_jobs == 6`, 6 different models are trained and simoultaneously such that Trial 1 and Trial 6 might run at the same time where the latter completes before the former. Therefore, informations from earlier trials my not be included yet in later trials, unless they have finished before the new trial was initialized. Successive trials with multithreading thus consider fewer previous trials (up to `n_jobs-1` fewer), though, when assessing sufficient trials, this is offset due to the increased optimization speed allowing for more trials to be considered in total.
#
# Successive optimization models will not be started till all multithreaded jobs complete of the initial model. Multithreading may cause warnings from models (CATBOOST!!). Supression thereof is not yet enabled.

# %%
result5 = AutomatedRegression(
    y=y,
    X=X,
    test_frac = 0.2,
    n_trial=15,
    n_jobs=6,                                   # < ----- MULTITHREADING
    write_folder='testdir/test5',
    metric_optimise = r2_score,
    metric_assess = [r2_score, median_absolute_error],
    optimisation_direction = 'maximize',
    models_to_optimize=['bayesianridge', 'lassolars', 'lightgbm'],
    models_to_assess=[ 'lassolars', 'bayesianridge'],
    )

# %%
result5.apply()
# Out:
# [I 2024-01-27 19:47:18,291] A new study created in RDB with name: regression_bayesianridge
# [I 2024-01-27 19:47:23,593] Trial 0 finished with value: 0.5720894353711085 and parameters: {'scaler': 'standard', 'max_iter': 17, 'tol': 37.8853169743874, 'alpha_1': 0.12997356877523447, 'alpha_2': 7.890188104473736, 'lambda_1': 11.911930245984179, 'lambda_2': 12.893110276489093, 'transformers': 'quantile_trans', 'n_quantiles': 3300}. Best is trial 0 with value: 0.5720894353711085.
# [I 2024-01-27 19:47:25,005] Trial 3 finished with value: 0.6114306610781624 and parameters: {'scaler': 'robust', 'max_iter': 16, 'tol': 90.0694323437771, 'alpha_1': 38.66820865485314, 'alpha_2': 2.6632233651340266e-06, 'lambda_1': 22.02149345786039, 'lambda_2': 0.004683587089862319, 'transformers': None}. Best is trial 3 with value: 0.6114306610781624.
# [I 2024-01-27 19:47:25,195] Trial 2 finished with value: 0.6114573150906468 and parameters: {'scaler': 'standard', 'max_iter': 248, 'tol': 17.37747299974762, 'alpha_1': 2.6995688751885398e-05, 'alpha_2': 8.51903681843214e-06, 'lambda_1': 0.00018394293900798019, 'lambda_2': 0.45570965887802356, 'transformers': None}. Best is trial 2 with value: 0.6114573150906468.
# [I 2024-01-27 19:47:25,494] Trial 1 finished with value: 0.6114574171267082 and parameters: {'scaler': 'standard', 'max_iter': 113, 'tol': 50.029880419803284, 'alpha_1': 2.283296865746401e-07, 'alpha_2': 0.00011949301524823023, 'lambda_1': 0.011782012161994638, 'lambda_2': 4.7802432176470056e-08, 'transformers': None}. Best is trial 1 with value: 0.6114574171267082.
# [I 2024-01-27 19:47:27,778] Trial 5 pruned.
# [I 2024-01-27 19:47:28,877] Trial 4 finished with value: 0.5720920029101536 and parameters: {'scaler': 'robust', 'max_iter': 241, 'tol': 21.486231021631, 'alpha_1': 6.833684087221987e-05, 'alpha_2': 0.0004998645926281548, 'lambda_1': 7.340780896302745e-05, 'lambda_2': 40.135568652033484, 'transformers': 'quantile_trans', 'n_quantiles': 2100}. Best is trial 1 with value: 0.6114574171267082.
# [I 2024-01-27 19:47:29,686] Trial 8 pruned.
# [I 2024-01-27 19:47:30,790] Trial 6 finished with value: 0.6113953480211631 and parameters: {'scaler': 'minmax', 'max_iter': 391, 'tol': 81.70361385889899, 'alpha_1': 6.617254928492377, 'alpha_2': 0.0006189413960003491, 'lambda_1': 10.132027138583066, 'lambda_2': 1.863063783601598e-08, 'transformers': None}. Best is trial 1 with value: 0.6114574171267082.
# [I 2024-01-27 19:47:31,325] Trial 7 pruned.
# [I 2024-01-27 19:47:31,562] Trial 11 pruned.
# [I 2024-01-27 19:47:32,275] Trial 13 pruned.
# [I 2024-01-27 19:47:32,640] Trial 9 finished with value: 0.5718441775497363 and parameters: {'scaler': 'minmax', 'max_iter': 93, 'tol': 2.154925149978949, 'alpha_1': 0.0002843802243614515, 'alpha_2': 0.0005665850880112739, 'lambda_1': 3.4444161303794854, 'lambda_2': 0.29945814478248967, 'transformers': 'quantile_trans', 'n_quantiles': 200}. Best is trial 1 with value: 0.6114574171267082.
# [I 2024-01-27 19:47:33,746] Trial 10 pruned.
# [I 2024-01-27 19:47:39,902] Trial 12 finished with value: 0.5720038533005217 and parameters: {'scaler': None, 'max_iter': 235, 'tol': 23.16355162748324, 'alpha_1': 3.736945684189961e-05, 'alpha_2': 2.8628580587190367e-08, 'lambda_1': 1.1310451198688488e-07, 'lambda_2': 9.916502382129234e-08, 'transformers': 'quantile_trans', 'n_quantiles': 3500}. Best is trial 1 with value: 0.6114574171267082.
# [I 2024-01-27 19:47:40,869] Trial 14 finished with value: 0.5720442972366554 and parameters: {'scaler': 'robust', 'max_iter': 39, 'tol': 48.15097173011644, 'alpha_1': 2.218672528078571e-06, 'alpha_2': 1.6379232062287208e-06, 'lambda_1': 0.00012261460029333113, 'lambda_2': 0.0023540138481221587, 'transformers': 'quantile_trans', 'n_quantiles': 2900}. Best is trial 1 with value: 0.6114574171267082.
# [I 2024-01-27 19:47:40,960] A new study created in RDB with name: regression_lassolars
# [I 2024-01-27 19:47:41,736] Trial 3 pruned.
# [I 2024-01-27 19:47:41,845] Trial 4 pruned.
# [I 2024-01-27 19:47:42,398] Trial 5 finished with value: 0.6114574645082997 and parameters: {'scaler': 'minmax', 'alpha': 1.9961550928623718e-07, 'random_state': 42, 'transformers': None}. Best is trial 5 with value: 0.6114574645082997.
# [I 2024-01-27 19:47:42,449] Trial 1 finished with value: 0.611456745810643 and parameters: {'scaler': 'standard', 'alpha': 5.8667225475047285e-08, 'random_state': 42, 'transformers': None}. Best is trial 5 with value: 0.6114574645082997.
# [I 2024-01-27 19:47:42,765] Trial 6 pruned.
# [I 2024-01-27 19:47:43,255] Trial 7 finished with value: 0.6113966390566509 and parameters: {'scaler': None, 'alpha': 0.0016625325631568196, 'random_state': 42, 'transformers': None}. Best is trial 5 with value: 0.6114574645082997.
# [I 2024-01-27 19:47:43,455] Trial 8 pruned.
# [I 2024-01-27 19:47:43,520] Trial 2 finished with value: 0.5720863319008719 and parameters: {'scaler': None, 'alpha': 4.561312369795238e-08, 'random_state': 42, 'transformers': 'quantile_trans', 'n_quantiles': 1000}. Best is trial 5 with value: 0.6114574645082997.
# [I 2024-01-27 19:47:43,779] Trial 0 finished with value: 0.5720901834318022 and parameters: {'scaler': 'robust', 'alpha': 3.005563243788769e-07, 'random_state': 42, 'transformers': 'quantile_trans', 'n_quantiles': 2600}. Best is trial 5 with value: 0.6114574645082997.
# [I 2024-01-27 19:47:43,850] Trial 11 pruned.
# [I 2024-01-27 19:47:43,865] Trial 9 pruned.
# [I 2024-01-27 19:47:44,181] Trial 14 pruned.
# [I 2024-01-27 19:47:44,447] Trial 12 finished with value: -0.00021537376071165682 and parameters: {'scaler': 'minmax', 'alpha': 7.199034871398501, 'random_state': 42, 'transformers': None}. Best is trial 5 with value: 0.6114574645082997.
# [I 2024-01-27 19:47:44,611] Trial 13 pruned.
# [I 2024-01-27 19:47:44,942] Trial 10 finished with value: 0.5720867319023062 and parameters: {'scaler': None, 'alpha': 9.430836567278793e-07, 'random_state': 42, 'transformers': 'quantile_trans', 'n_quantiles': 1700}. Best is trial 5 with value: 0.6114574645082997.
# [I 2024-01-27 19:47:45,009] A new study created in RDB with name: regression_lightgbm
# [I 2024-01-27 19:47:46,896] Trial 0 finished with value: 0.3986080321390035 and parameters: {'scaler': None, 'objective': 'regression', 'max_depth': 16, 'n_estimators': 167, 'max_bin': 255, 'min_gain_to_split': 14.932576631708837, 'lambda_l1': 0.0007393950322070993, 'lambda_l2': 0.0007381226035870763, 'num_leaves': 66, 'feature_fraction': 0.1600434582511689, 'bagging_fraction': 0.5450573625287546, 'bagging_freq': 5, 'min_child_samples': 59, 'random_state': 42, 'verbosity': -1, 'transformers': 'quantile_trans', 'n_quantiles': 300}. Best is trial 0 with value: 0.3986080321390035.
# [I 2024-01-27 19:47:53,766] Trial 3 pruned.
# [I 2024-01-27 19:47:57,593] Trial 6 pruned.
# [I 2024-01-27 19:47:58,653] Trial 1 pruned.
# [I 2024-01-27 19:48:00,055] Trial 9 pruned.
# [I 2024-01-27 19:48:01,307] Trial 2 pruned.
# [I 2024-01-27 19:48:02,541] Trial 7 finished with value: 0.5329589906731169 and parameters: {'scaler': 'standard', 'objective': 'regression', 'max_depth': 11, 'n_estimators': 67, 'max_bin': 127, 'min_gain_to_split': 2.692631168316315, 'lambda_l1': 0.010514024450163474, 'lambda_l2': 1.8390832238819153e-07, 'num_leaves': 19, 'feature_fraction': 0.8070503987301637, 'bagging_fraction': 0.2223904083078135, 'bagging_freq': 4, 'min_child_samples': 98, 'random_state': 42, 'verbosity': -1, 'transformers': 'quantile_trans', 'n_quantiles': 2700}. Best is trial 7 with value: 0.5329589906731169.
# [I 2024-01-27 19:48:04,551] Trial 10 pruned.
# [I 2024-01-27 19:48:07,889] Trial 8 pruned.
# [I 2024-01-27 19:48:09,999] Trial 4 finished with value: 0.7873432289175948 and parameters: {'scaler': 'minmax', 'objective': 'regression', 'max_depth': 7, 'n_estimators': 347, 'max_bin': 63, 'min_gain_to_split': 4.1810043772521315, 'lambda_l1': 0.00040689519915020913, 'lambda_l2': 0.00047916815934470885, 'num_leaves': 155, 'feature_fraction': 0.8990199375783284, 'bagging_fraction': 0.4972535796942724, 'bagging_freq': 3, 'min_child_samples': 55, 'random_state': 42, 'verbosity': -1, 'transformers': None}. Best is trial 4 with value: 0.7873432289175948.
# [I 2024-01-27 19:48:16,532] Trial 11 pruned.
# [I 2024-01-27 19:48:18,333] Trial 5 finished with value: 0.8086045318143444 and parameters: {'scaler': 'standard', 'objective': 'regression', 'max_depth': 7, 'n_estimators': 331, 'max_bin': 127, 'min_gain_to_split': 1.0778193223616206, 'lambda_l1': 0.03463301726511158, 'lambda_l2': 0.15357141187726145, 'num_leaves': 166, 'feature_fraction': 0.9231573020018468, 'bagging_fraction': 0.2767882509990274, 'bagging_freq': 5, 'min_child_samples': 23, 'random_state': 42, 'verbosity': -1, 'transformers': None}. Best is trial 5 with value: 0.8086045318143444.
# [I 2024-01-27 19:48:18,890] Trial 12 finished with value: 0.6737940516314538 and parameters: {'scaler': 'minmax', 'objective': 'regression', 'max_depth': 11, 'n_estimators': 232, 'max_bin': 255, 'min_gain_to_split': 1.6189045578976384, 'lambda_l1': 0.0002872661775892749, 'lambda_l2': 0.0014354587021237974, 'num_leaves': 173, 'feature_fraction': 0.45065821210549184, 'bagging_fraction': 0.5608606356242094, 'bagging_freq': 2, 'min_child_samples': 3, 'random_state': 42, 'verbosity': -1, 'transformers': 'quantile_trans', 'n_quantiles': 3300}. Best is trial 5 with value: 0.8086045318143444.
# [I 2024-01-27 19:48:19,376] Trial 14 pruned.
# [I 2024-01-27 19:48:23,237] Trial 13 finished with value: 0.8189315550500964 and parameters: {'scaler': 'minmax', 'objective': 'regression', 'max_depth': 20, 'n_estimators': 98, 'max_bin': 127, 'min_gain_to_split': 1.4636268195809703, 'lambda_l1': 7.687956611088248e-06, 'lambda_l2': 0.0041731736791198355, 'num_leaves': 186, 'feature_fraction': 0.8996708776380552, 'bagging_fraction': 0.6742994877414632, 'bagging_freq': 6, 'min_child_samples': 31, 'random_state': 42, 'verbosity': -1, 'transformers': None}. Best is trial 13 with value: 0.8189315550500964.
# [I 2024-01-27 19:48:23,248] Using an existing study with name 'regression_lassolars' instead of creating a new one.
# [I 2024-01-27 19:48:23,270] Using an existing study with name 'regression_bayesianridge' instead of creating a new one.

# %% [markdown]
# ## Regression #7: feature importance
# The `shap` python package is usefull for understanding the importance of particular features in your dataset in making predictions. For details on shap visit the [shap documentation](https://shap.readthedocs.io/en/latest/index.html).

# %%
shap_output = result5.model_feature_importance()
# Out:
# Clustering...
# Using 200 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
# Calculating Shapely values...
# 100%|██████████| 200/200 [00:23<00:00,  8.66it/s]

# %% [markdown]
# ## Regression #8: reloading a model
# Lets reload one of our created models without having to instatiate a regression class. The final stack models are saved in the specified directory. They can be reloaded using `joblib`.

# %%
import joblib

model = joblib.load('testdir/test5/stacked_model.joblib')

model.predict(X)
# Out:
# array([4.1485153 , 3.99622919, 3.67111691, ..., 0.15507846, 0.3094387 ,
#        0.5126925 ])
